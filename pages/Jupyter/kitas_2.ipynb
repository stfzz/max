# %%
import pandas as pd
import numpy as np
import datetime as dt
from collections import Counter
import ipywidgets as widgets
import io

# %%
fn = "prospetto rendicontazione via combattenti 2019.xlsx"
fn2 = "prospetto rendicontazione via combattenti 2019_bis.xlsx"

# %%
df = pd.read_excel(fn,0)
df2 = pd.read_excel(fn2,0)

# %%
df = df.drop(["Unnamed: 6", "Unnamed: 7"], axis=1)
df.columns = [
        "Cognome",
        "Nome",
        "utente",
        "ComuneProvenienza",
        "DataInizio",
        "DataFine",
    ]
df2 = df2.drop(["Unnamed: 6", "Unnamed: 7"], axis=1)
df2.columns = [
        "Cognome",
        "Nome",
        "utente",
        "ComuneProvenienza",
        "DataInizio",
        "DataFine",
    ]

# %%
microstruttura = df.iloc[1]
microstruttura = microstruttura[1]
ente = df.iloc[2]
ente = ente[1]
df.insert(0, "Microstruttura", microstruttura)
df.insert(0, "Ente", ente)

# %%
ente
# Out:
# 'Cooperativa sociale Coccinella'

# %%
microstruttura = df2.iloc[1]
microstruttura = microstruttura[1]
df2.insert(0, "Microstruttura", microstruttura)
ente = df2.iloc[2]
ente = ente[2]
df2.insert(0, "Ente", ente)

# %%
df2
# Out:
#                            Ente  \
# 0  Cooperativa Sociale Babycoop
# 1  Cooperativa Sociale Babycoop
# 2  Cooperativa Sociale Babycoop
# 3  Cooperativa Sociale Babycoop
# 4  Cooperativa Sociale Babycoop
# 5  Cooperativa Sociale Babycoop
# 6  Cooperativa Sociale Babycoop
# 7  Cooperativa Sociale Babycoop
#
#                                       Microstruttura            Cognome  \
# 0  Bolzano, Via Combattenti, 4, Coccinella (azien...                NaN
# 1  Bolzano, Via Combattenti, 4, Coccinella (azien...     Microstruttura
# 2  Bolzano, Via Combattenti, 4, Coccinella (azien...       Ente gestore
# 3  Bolzano, Via Combattenti, 4, Coccinella (azien...                NaN
# 4  Bolzano, Via Combattenti, 4, Coccinella (azien...            bambini
# 5  Bolzano, Via Combattenti, 4, Coccinella (azien...            cognome
# 6  Bolzano, Via Combattenti, 4, Coccinella (azien...  PIETROBON FILIPPO
# 7  Bolzano, Via Combattenti, 4, Coccinella (azien...              Tizio
#
# ...

# %%
df2 = df2.drop(labels=range(0, 6), axis=0)
df = df.drop(labels=range(0, 6), axis=0)
df.columns
df2.columns
# Out:
# Index(['Ente', 'Microstruttura', 'Cognome', 'Nome', 'utente',
#        'ComuneProvenienza', 'DataInizio', 'DataFine'],
#       dtype='object')

# %%
df
# Out:
#                               Ente  \
# 6   Cooperativa sociale Coccinella
# 7   Cooperativa sociale Coccinella
# 8   Cooperativa sociale Coccinella
# 9   Cooperativa sociale Coccinella
# 10  Cooperativa sociale Coccinella
# 11  Cooperativa sociale Coccinella
# 12  Cooperativa sociale Coccinella
# 13  Cooperativa sociale Coccinella
# 14  Cooperativa sociale Coccinella
#
#                                        Microstruttura            Cognome  \
# 6   Bolzano, Via Combattenti, 4, Coccinella (azien...              Borgo
# 7   Bolzano, Via Combattenti, 4, Coccinella (azien...              Amato
# 8   Bolzano, Via Combattenti, 4, Coccinella (azien...             Gulino
# 9   Bolzano, Via Combattenti, 4, Coccinella (azien...             Furlan
# 10  Bolzano, Via Combattenti, 4, Coccinella (azien...         GUIBERTEAu
# 11  Bolzano, Via Combattenti, 4, Coccinella (azien...         FRASSANITO
# 12  Bolzano, Via Combattenti, 4, Coccinella (azien...   SCAFURO GIOVANNI
# ...

# %%
dfout=None

# %%
dfout = pd.DataFrame(columns=df.columns)

# %%
dfout
# Out:
# Empty DataFrame
# Columns: [Ente, Microstruttura, Cognome, Nome, utente, ComuneProvenienza, DataInizio, DataFine]
# Index: []

# %%
dfout = df.copy()

# %%
dfout = pd.concat([dfout, df2])

# %%
dfout
# Out:
#                               Ente  \
# 6   Cooperativa sociale Coccinella
# 7   Cooperativa sociale Coccinella
# 8   Cooperativa sociale Coccinella
# 9   Cooperativa sociale Coccinella
# 10  Cooperativa sociale Coccinella
# 11  Cooperativa sociale Coccinella
# 12  Cooperativa sociale Coccinella
# 13  Cooperativa sociale Coccinella
# 14  Cooperativa sociale Coccinella
# 6     Cooperativa Sociale Babycoop
# 7     Cooperativa Sociale Babycoop
#
#                                        Microstruttura            Cognome  \
# 6   Bolzano, Via Combattenti, 4, Coccinella (azien...              Borgo
# 7   Bolzano, Via Combattenti, 4, Coccinella (azien...              Amato
# 8   Bolzano, Via Combattenti, 4, Coccinella (azien...             Gulino
# 9   Bolzano, Via Combattenti, 4, Coccinella (azien...             Furlan
# 10  Bolzano, Via Combattenti, 4, Coccinella (azien...         GUIBERTEAu
# 11  Bolzano, Via Combattenti, 4, Coccinella (azien...         FRASSANITO
# ...

# %%
df["Cognome"].count()
# Out:
# 9

# %%
c1 = dfout.groupby("Cognome")["DataInizio"].transform("nunique") == 1
c2 = dfout.groupby("Cognome")["Ente"].transform("nunique") > 1

# %%
dfout[c1 & c2]
# Out:
#    NomeCompleto                            Ente  \
# 14   Tizio Caio  Cooperativa sociale Coccinella
# 7    Tizio Caio    Cooperativa Sociale Babycoop
#
#                                        Microstruttura Cognome  Nome    utente  \
# 14  Bolzano, Via Combattenti, 4, Coccinella (azien...   Tizio  Caio  comunale
# 7   Bolzano, Via Combattenti, 4, Coccinella (azien...   Tizio  Caio  comunale
#
#    ComuneProvenienza           DataInizio             DataFine
# 14   Bozen / Bolzano  2017-01-15 00:00:00  2020-08-31 00:00:00
# 7    Bozen / Bolzano  2017-01-15 00:00:00  2020-08-31 00:00:00

# %%
dfout
# Out:
#                  NomeCompleto                            Ente  \
# 6                 Borgo Alice  Cooperativa sociale Coccinella
# 7               Amato Michele  Cooperativa sociale Coccinella
# 8                Gulino Alexa  Cooperativa sociale Coccinella
# 9                  Furlan Leo  Cooperativa sociale Coccinella
# 10            GUIBERTEAu Gael  Cooperativa sociale Coccinella
# 11            FRASSANITO Alex  Cooperativa sociale Coccinella
# 12  SCAFURO GIOVANNI Giovanni  Cooperativa sociale Coccinella
# 13                        NaN  Cooperativa sociale Coccinella
# 14                 Tizio Caio  Cooperativa sociale Coccinella
# 6                         NaN    Cooperativa Sociale Babycoop
# 7                  Tizio Caio    Cooperativa Sociale Babycoop
#
#                                        Microstruttura            Cognome  \
# 6   Bolzano, Via Combattenti, 4, Coccinella (azien...              Borgo
# ...

# %%
dfout.insert(0, "NomeCompleto", dfout["Cognome"] + " " + dfout["Nome"])

# %%
dfout
# Out:
#                  NomeCompleto                            Ente  \
# 6                 Borgo Alice  Cooperativa sociale Coccinella
# 7               Amato Michele  Cooperativa sociale Coccinella
# 8                Gulino Alexa  Cooperativa sociale Coccinella
# 9                  Furlan Leo  Cooperativa sociale Coccinella
# 10            GUIBERTEAu Gael  Cooperativa sociale Coccinella
# 11            FRASSANITO Alex  Cooperativa sociale Coccinella
# 12  SCAFURO GIOVANNI Giovanni  Cooperativa sociale Coccinella
# 13                        NaN  Cooperativa sociale Coccinella
# 14                 Tizio Caio  Cooperativa sociale Coccinella
# 6                         NaN    Cooperativa Sociale Babycoop
# 7                  Tizio Caio    Cooperativa Sociale Babycoop
#
#                                        Microstruttura            Cognome  \
# 6   Bolzano, Via Combattenti, 4, Coccinella (azien...              Borgo
# ...
