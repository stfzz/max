# %%
import pandas as pd
import numpy as np
#import streamlit as st
import datetime as dt
from collections import Counter
fn = './storico (copy).xlsx'
#fn = './errorfiles/Erklärung_Gemeinde_Aldein_2020.xlsx'

# %%
df = pd.read_excel(fn)

# %%
df
# Out:
#      Unnamed: 0                                      filename  \
# 0            11           Erklärung_Gemeinde_Algund_2020.xlsx
# 1            16           Erklärung_Gemeinde_Algund_2020.xlsx
# 2            11            Erklärung_Gemeinde_Bozen_2020.xlsx
# 3            12            Erklärung_Gemeinde_Bozen_2020.xlsx
# 4            13            Erklärung_Gemeinde_Bozen_2020.xlsx
# ..          ...                                           ...
# 129           9         Erklärung_Gemeinde_Tscherms_2020.xlsx
# 130           8       Erklärung_Gemeinde_Villanders_2020.xlsx
# 131          10  Erklärung_Gemeinde_Völs am Schlern_2020.xlsx
# 132          13  Erklärung_Gemeinde_Völs am Schlern_2020.xlsx
# 133          18         Erklärung_Gemeinde_Welsberg_2020.xlsx
#
#     Cognome e nome bambino                                     Ente  \
# 0              FLARER THEO  Sozialgenossenschaft Tagesmütter - Gen.
# 1           MIRANDOLA LENZ  Sozialgenossenschaft Tagesmütter - Gen.
# ...

# %%
condizionlogica1 = (
        df.groupby("Codice fiscale")["Codice fiscale"].transform("count") > 1
     )

# %%
condizionlogica1
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 129     True
# 130    False
# 131     True
# 132    False
# 133    False
# Name: Codice fiscale, Length: 134, dtype: bool

# %%
df[condizionlogica1]
# Out:
#      Unnamed: 0                                      filename  \
# 2            11            Erklärung_Gemeinde_Bozen_2020.xlsx
# 3            12            Erklärung_Gemeinde_Bozen_2020.xlsx
# 6            16            Erklärung_Gemeinde_Bozen_2020.xlsx
# 7            19            Erklärung_Gemeinde_Bozen_2020.xlsx
# 14           42            Erklärung_Gemeinde_Bozen_2020.xlsx
# 26            8         Erklärung_Gemeinde_Branzoll_2020.xlsx
# 43            8       Erklärung_Gemeinde_Freienfeld_2020.xlsx
# 44            9       Erklärung_Gemeinde_Freienfeld_2020.xlsx
# 45            9         Erklärung_Gemeinde_Gargazon_2020.xlsx
# 46            9          Erklärung_Gemeinde_Klausen_2020.xlsx
# 47            8             Erklärung_Gemeinde_Laas_2020.xlsx
# 51           11             Erklärung_Gemeinde_Lana_2020.xlsx
# 61           37             Erklärung_Gemeinde_Lana_2020.xlsx
# 68           12          Erklärung_Gemeinde_Leifers_2020.xlsx
# ...

# %%
df
# Out:
#      Unnamed: 0                                      filename  \
# 0            11           Erklärung_Gemeinde_Algund_2020.xlsx
# 1            16           Erklärung_Gemeinde_Algund_2020.xlsx
# 2            11            Erklärung_Gemeinde_Bozen_2020.xlsx
# 3            12            Erklärung_Gemeinde_Bozen_2020.xlsx
# 4            13            Erklärung_Gemeinde_Bozen_2020.xlsx
# ..          ...                                           ...
# 129           9         Erklärung_Gemeinde_Tscherms_2020.xlsx
# 130           8       Erklärung_Gemeinde_Villanders_2020.xlsx
# 131          10  Erklärung_Gemeinde_Völs am Schlern_2020.xlsx
# 132          13  Erklärung_Gemeinde_Völs am Schlern_2020.xlsx
# 133          18         Erklärung_Gemeinde_Welsberg_2020.xlsx
#
#     Cognome e nome bambino                                     Ente  \
# 0              FLARER THEO  Sozialgenossenschaft Tagesmütter - Gen.
# 1           MIRANDOLA LENZ  Sozialgenossenschaft Tagesmütter - Gen.
# ...

# %%
condizionelogica2 =  (df.groupby("Codice fiscale")["Comune"].transform("nunique") > 1)

# %%
condizionelogica2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 129     True
# 130    False
# 131     True
# 132    False
# 133    False
# Name: Comune, Length: 134, dtype: bool

# %%
df[condizionelogica2]
# Out:
#      Unnamed: 0                                      filename  \
# 6            16            Erklärung_Gemeinde_Bozen_2020.xlsx
# 7            19            Erklärung_Gemeinde_Bozen_2020.xlsx
# 14           42            Erklärung_Gemeinde_Bozen_2020.xlsx
# 26            8         Erklärung_Gemeinde_Branzoll_2020.xlsx
# 43            8       Erklärung_Gemeinde_Freienfeld_2020.xlsx
# 44            9       Erklärung_Gemeinde_Freienfeld_2020.xlsx
# 45            9         Erklärung_Gemeinde_Gargazon_2020.xlsx
# 46            9          Erklärung_Gemeinde_Klausen_2020.xlsx
# 47            8             Erklärung_Gemeinde_Laas_2020.xlsx
# 51           11             Erklärung_Gemeinde_Lana_2020.xlsx
# 61           37             Erklärung_Gemeinde_Lana_2020.xlsx
# 68           12          Erklärung_Gemeinde_Leifers_2020.xlsx
# 69           14          Erklärung_Gemeinde_Leifers_2020.xlsx
# 75           11             Erklärung_Gemeinde_Mals_2020.xlsx
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'filename', 'Cognome e nome bambino', 'Ente', 'Comune',
#        'Data di nascita', 'Codice fiscale',
#        'Assistente domiciliare all'infanzia',
#        'Comune di residenza assistente domiciliare all'infanzia',
#        'Data inizio contratto (o data inizio assistenza se diversa)',
#        'GiorniAssistenzaAnnoRiferimento',
#        'Data fine contratto\n(o data fine assistenza se diversa) *',
#        'Ore di assistenza \n ai sensi della delibera\nn. 666/2019',
#        'Ore contrattualizzate non erogate\nai sensi della delibera\nn. 543_1025/2020',
#        'Ore contrattualizzate non erogate\nai sensi della delibera\nn. 733/2020',
#        'Ore contrattualizzate non erogate\nnella fase 2 (finanziamento compensativo)',
#        'Ore totali rendicontate per il 2020', 'errCodFisc1', 'errCodFisc2',
#        'errAgeChild', 'errInizioMinoreFine', 'errErrorePresenza',
#        'errErroreDati543', 'errFineAssistenzaMax4Anni', 'errKindergarten_1',
# ...

# %%
condizione = df["Cognome e nome bambino"].str.contains("[@_!#$%^&*()<>?/|}{~:]") == True

# %%
df[condizione]
# Out:
#      Unnamed: 0                                          filename  \
# 3            12                Erklärung_Gemeinde_Bozen_2020.xlsx
# 6            16                Erklärung_Gemeinde_Bozen_2020.xlsx
# 35           15  Erklärung_Gemeinde_Eppan a.d. Weinstr._2020.xlsx
# 45            9             Erklärung_Gemeinde_Gargazon_2020.xlsx
# 51           11                 Erklärung_Gemeinde_Lana_2020.xlsx
# 54           19                 Erklärung_Gemeinde_Lana_2020.xlsx
# 64           43                 Erklärung_Gemeinde_Lana_2020.xlsx
# 75           11                 Erklärung_Gemeinde_Mals_2020.xlsx
# 84           14               Erklärung_Gemeinde_Mölten_2020.xlsx
# 85           15               Erklärung_Gemeinde_Mölten_2020.xlsx
# 101           9        Erklärung_Gemeinde_Rasen-Antholz_2020.xlsx
# 103          15        Erklärung_Gemeinde_Rasen-Antholz_2020.xlsx
# 106           9           Erklärung_Gemeinde_Ratschings_2020.xlsx
# ...
